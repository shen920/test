# %% [markdown]
# <a href="https://colab.research.google.com/github/shen920/test/blob/main/BesselFunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Default title text
import numpy as np
from scipy.special import jv
import matplotlib.pyplot as plt

x = np.linspace(-20,20,1000)

for i in range(3):
  J = jv(i,x)
  plt.plot(x,J, label=r'$J_' + str(i) + '(x)$')

plt.legend()
plt.title('BESSEL FUNCTION', fontweight='bold', fontsize=20)
plt.xlabel('x', fontweight = 'bold', fontsize = 16)
plt.ylabel('$J_v(x)$', fontweight='bold', fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# ## hpsh
# $ F_B = q v \times B $
#
#
#
# 1. General Relativity
# 2. Modern Physics
#
#
# ```
# # This is formatted as code
# import numpy as np
# import matplotlib.pyplot as plt
# ```

# %%
import pandas as pd
